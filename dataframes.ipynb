# %%
from pydataset import data

# %% [markdown]
# All the datasets loaded from the pydataset library will be pandas dataframes.

# %% [markdown]
# 1) Copy the code from the lesson to create a dataframe full of student grades.

# %%
import pandas as pd
import numpy as np

np.random.seed(123)

students = ['Sally', 'Jane', 'Suzie', 'Billy', 'Ada', 'John', 'Thomas',
            'Marie', 'Albert', 'Richard', 'Isaac', 'Alan']

# randomly generate scores for each student for each subject
# note that all the values need to have the same length here
math_grades = np.random.randint(low=60, high=100, size=len(students))
english_grades = np.random.randint(low=60, high=100, size=len(students))
reading_grades = np.random.randint(low=60, high=100, size=len(students))

df = pd.DataFrame({'name': students,
                   'math': math_grades,
                   'english': english_grades,
                   'reading': reading_grades})
df
# Out:
#        name  math  english  reading
# 0     Sally    62       85       80
# 1      Jane    88       79       67
# 2     Suzie    94       74       95
# 3     Billy    98       96       88
# 4       Ada    77       92       98
# 5      John    79       76       93
# 6    Thomas    82       64       81
# 7     Marie    93       63       90
# 8    Albert    92       62       87
# 9   Richard    69       80       94
# 10    Isaac    92       99       93
# 11     Alan    92       62       72

# %% [markdown]
# 1a) Create a column named passing_english that indicates whether each student has a passing grade in reading.

# %%
df['passing_english'] = df.english >= 70 
#"series['new_column_name']" creates a new column 
#in that series. the column will be filled by
#the data proceeding the equal sign
#in this case it will be filled with T for 
#all english grades 70 and F for the remainder
df
# Out:
#        name  math  english  reading  passing_english
# 0     Sally    62       85       80             True
# 1      Jane    88       79       67             True
# 2     Suzie    94       74       95             True
# 3     Billy    98       96       88             True
# 4       Ada    77       92       98             True
# 5      John    79       76       93             True
# 6    Thomas    82       64       81            False
# 7     Marie    93       63       90            False
# 8    Albert    92       62       87            False
# 9   Richard    69       80       94             True
# 10    Isaac    92       99       93             True
# 11     Alan    92       62       72            False

# %% [markdown]
# 1b) Sort the english grades by the passing_english column. How are duplicates handled?

# %%
df.sort_values('passing_english')
#"series.sort_values('condition')" will sort 
#the series by the condition
#in this instance the values will be sorted(ascending)
#based off of T/F values

#The duplicates are sorted by the index value.
# Out:
#        name  math  english  reading  passing_english
# 6    Thomas    82       64       81            False
# 7     Marie    93       63       90            False
# 8    Albert    92       62       87            False
# 11     Alan    92       62       72            False
# 0     Sally    62       85       80             True
# 1      Jane    88       79       67             True
# 2     Suzie    94       74       95             True
# 3     Billy    98       96       88             True
# 4       Ada    77       92       98             True
# 5      John    79       76       93             True
# 9   Richard    69       80       94             True
# 10    Isaac    92       99       93             True

# %% [markdown]
# 1c) Sort the english grades first by passing_english and then by student name. All the students that are failing english should be first, and within the students that are failing english they should be ordered alphabetically. The same should be true for the students passing english. (Hint: you can pass a list to the .sort_values method)

# %%
df.sort_values(['passing_english', 'name'])
#the values in the dataframe can be sorted by a list
#the values will be sorted by T/F from 
#'passing_english' then by 'name'
# Out:
#        name  math  english  reading  passing_english
# 11     Alan    92       62       72            False
# 8    Albert    92       62       87            False
# 7     Marie    93       63       90            False
# 6    Thomas    82       64       81            False
# 4       Ada    77       92       98             True
# 3     Billy    98       96       88             True
# 10    Isaac    92       99       93             True
# 1      Jane    88       79       67             True
# 5      John    79       76       93             True
# 9   Richard    69       80       94             True
# 0     Sally    62       85       80             True
# 2     Suzie    94       74       95             True

# %% [markdown]
# 1d) Sort the english grades first by passing_english, and then by the actual english grade, similar to how we did in the last step.

# %%
df.sort_values(['passing_english', 'english'])
#just like above, the values from the database will
#be sorted by the T/F values from 'passing_english'
#then by the grades from 'english'

#you can apply ascending values to both conditions
#df.sort_values(['passing_english', 'english'], ascending = [False, False])
# Out:
#        name  math  english  reading  passing_english
# 8    Albert    92       62       87            False
# 11     Alan    92       62       72            False
# 7     Marie    93       63       90            False
# 6    Thomas    82       64       81            False
# 2     Suzie    94       74       95             True
# 5      John    79       76       93             True
# 1      Jane    88       79       67             True
# 9   Richard    69       80       94             True
# 0     Sally    62       85       80             True
# 4       Ada    77       92       98             True
# 3     Billy    98       96       88             True
# 10    Isaac    92       99       93             True

# %% [markdown]
# 1e) Calculate each students overall grade and add it as a column on the dataframe. The overall grade is the average of the math, english, and reading grades.

# %%
df['overall_grade'] = (df.math + df.english + df.reading) / 3
df
#to find the overall grade you first need to add the grades from 
#'math', 'english', and 'reading' then divide it by 3
#this value will be stored in the new column created
#called 'overall_grade'

#grab all rows, columns 1-4 excluding 4
#sum them and assign them to total
#total = df.iloc[:, 1:4].sum(axis=1)
#df['overall_grade'] = round(totals/3,0).astype(int)

#another way which is inclusive
#df.loc[: 'math':'reading']
# Out:
#        name  math  english  reading  passing_english  overall_grade
# 0     Sally    62       85       80             True      75.666667
# 1      Jane    88       79       67             True      78.000000
# 2     Suzie    94       74       95             True      87.666667
# 3     Billy    98       96       88             True      94.000000
# 4       Ada    77       92       98             True      89.000000
# 5      John    79       76       93             True      82.666667
# 6    Thomas    82       64       81            False      75.666667
# 7     Marie    93       63       90            False      82.000000
# 8    Albert    92       62       87            False      80.333333
# 9   Richard    69       80       94             True      81.000000
# 10    Isaac    92       99       93             True      94.666667
# 11     Alan    92       62       72            False      75.333333

# %% [markdown]
# 2) Load the mpg dataset. Read the documentation for the dataset and use it for the following questions:

# %%
data('mpg', show_doc=True) # view the documentation for the dataset
# Out:
# mpg
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Fuel economy data from 1999 and 2008 for 38 popular models of car
#
# ### Description
#
# This dataset contains a subset of the fuel economy data that the EPA makes
# available on http://fueleconomy.gov. It contains only models which had a new
# release every year between 1999 and 2008 - this was used as a proxy for the
# popularity of the car.
#
# ### Usage
#
#     data(mpg)
#
# ### Format
#
# A data frame with 234 rows and 11 variables
#
# ### Details
#
#   * manufacturer.
#
#   * model.
#
#   * displ. engine displacement, in litres
#
#   * year.
#
#   * cyl. number of cylinders
#
#   * trans. type of transmission
#
#   * drv. f = front-wheel drive, r = rear wheel drive, 4 = 4wd
#
#   * cty. city miles per gallon
#
#   * hwy. highway miles per gallon
#
#   * fl.
#
#   * class.

# %%
mpg = data('mpg') # load the dataset and store it in a variable

# %% [markdown]
# 2a) How many rows and columns are there?

# %%
mpg.shape
#this function shows the number of rows and columns
# in the dataframe

#there are 234 rows and 11 columns
# Out:
# (234, 11)

# %% [markdown]
# 2b) What are the data types of each column?

# %%
#this function shows the data type in each column
mpg.dtypes
# Out:
# manufacturer     object
# model            object
# displ           float64
# year              int64
# cyl               int64
# trans            object
# drv              object
# cty               int64
# hwy               int64
# fl               object
# class            object
# dtype: object

# %% [markdown]
# 2c) Summarize the dataframe with .info and .describe

# %%
mpg.info
mpg.describe
# Out:
# <bound method NDFrame.describe of     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# ...

# %% [markdown]
# 2d) Rename the cty column to city.

# %%
mpg.rename(columns = {'cty': 'city'}, inplace = True)
#'dataframe.rename(columns = {'column_name': 'new_column_name'})'
#the blanket function above will rename a column within a dataframe
#to the name of the 'new_column_name'
#to make the change permanent on the existing dataframe,
# add a comma and 'inplace = True' after the column names
#but within the parenthesis

#can change several names at once
#mpg.rename(columns = {'cty': 'city', 'hwy': 'highway'}, inplace = True)
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ...

# %% [markdown]
# 2e) Rename the hwy column to highway.

# %%
mpg.rename(columns = {'hwy': 'highway'}, inplace = True)
#in the mpg dataframe, we want to change the 'hwy' column
#name into 'highway', and make that change permanent 
#on the main dataframe (inplace = True)
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
#        class
# 1    compact
# 2    compact
# ...

# %%
#another way is 
#mpg.columns.to_list()
#rename the list and then save it back to mpg.columns

# %% [markdown]
# 2f) Do any cars have better city mileage than highway mileage?

# %%
mpg[mpg.city > mpg.highway]
#within the mpg dataframe, show all the cars
#that the city mileage is better than the highway mileage

#No, there are no cars that have better 
#city mileage than highway mileage
# Out:
# Empty DataFrame
# Columns: [manufacturer, model, displ, year, cyl, trans, drv, city, highway, fl, class]
# Index: []

# %% [markdown]
# 2g) Create a column named mileage_difference this column should contain the difference between highway and city mileage for each car.

# %%
mpg['mileage_difference'] = mpg.highway - mpg.city
#in the mpg dataframe, create a column named 'mileage difference'
# and fill it with the difference between the 'highway'
#column from the 'city' column
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
#        class  mileage_difference
# ...

# %% [markdown]
# 2h) Which car (or cars) has the highest mileage difference?

# %%
mpg[mpg.mileage_difference == mpg.mileage_difference.max()]
#in the mpg dataframe, retrieve the data from the
#'mileage_difference' column and only return(==) 
#the max value from that column
# Out:
#     manufacturer       model  displ  year  cyl     trans drv  city  highway  \
# 107        honda       civic    1.8  2008    4  auto(l5)   f    24       36
# 223   volkswagen  new beetle    1.9  1999    4  auto(l4)   f    29       41
#
#     fl       class  mileage_difference
# 107  c  subcompact                  12
# 223  d  subcompact                  12

# %% [markdown]
# 2i) Which compact class car has the lowest highway mileage? The best?

# %%
compact_car = mpg[mpg['class'] == "compact"]
#create a subdataframe called 'compact_car' that will
#access the mpg dataframe and retrieve cars under the 
#'class' column that are identified (==) as 'compact'
compact_lowest_highway = compact_car[compact_car.highway ==  compact_car.highway.min()]
#create a subdataframe called 'compact_lowest_highway' that
#will retrieve cars from the subdataframe called 'compact_car'
#under the column called 'highway' that is equal (==) to the lowest value(min)
compact_lowest_highway

compact_best_highway = compact_car[compact_car.highway ==  compact_car.highway.max()]
#create a subdataframe called 'compact_best_highway' that
#will retrieve cars from the subdataframe called 'compact_car'
#under the column called 'highway' that is equal (==) to the highest value(max)
compact_best_highway
# Out:
#     manufacturer  model  displ  year  cyl       trans drv  city  highway fl  \
# 213   volkswagen  jetta    1.9  1999    4  manual(m5)   f    33       44  d
#
#        class  mileage_difference
# 213  compact                  11

# %% [markdown]
# 2j) Create a column named average_mileage that is the mean of the city and highway mileage.

# %%
mpg['average_mileage'] = (mpg.highway + mpg.city) / 2
#in the mpg dataframe, create a column called 'average_mileage'
# and fill it with the sum of the 'highway' and 'city' columns,
#then divide it by two
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
# ...

# %% [markdown]
# 2k) Which dodge car has the best average mileage? The worst?

# %%
dodge = mpg[mpg.manufacturer == 'dodge']
#create a subdataframe called 'dodge' that will
#access the mpg dataframe and retrieve cars under the 
#'manufacturer' column that are identified (==) as 'dodge'
dodge_best_mileage = dodge[dodge.average_mileage == dodge.average_mileage.max()]
#create a subdataframe called 'dodge_best_mileage' that
#will retrieve cars from the subdataframe called 'dodge'
#under the column called 'average_mileage' that is equal (==) to the highest value(max)
dodge_best_mileage

dodge_worst_mileage = dodge[dodge.average_mileage == dodge.average_mileage.min()]
#create a subdataframe called 'dodge_worst_mileage' that
#will retrieve cars from the subdataframe called 'dodge'
#under the column called 'average_mileage' that is equal (==) to the lowest value(min)
dodge_worst_mileage
# Out:
#    manufacturer                model  displ  year  cyl       trans drv  city  \
# 55        dodge    dakota pickup 4wd    4.7  2008    8    auto(l5)   4     9
# 60        dodge          durango 4wd    4.7  2008    8    auto(l5)   4     9
# 66        dodge  ram 1500 pickup 4wd    4.7  2008    8    auto(l5)   4     9
# 70        dodge  ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4     9
#
#     highway fl   class  mileage_difference  average_mileage
# 55       12  e  pickup                   3             10.5
# 60       12  e     suv                   3             10.5
# 66       12  e  pickup                   3             10.5
# 70       12  e  pickup                   3             10.5

# %% [markdown]
# 3) Load the Mammals dataset. Read the documentation for it, and use the data to answer these questions:

# %%
data('Mammals', show_doc=True) # view the documentation for the dataset
# Out:
# Mammals
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Garland(1983) Data on Running Speed of Mammals
#
# ### Description
#
# Observations on the maximal running speed of mammal species and their body
# mass.
#
# ### Usage
#
#     data(Mammals)
#
# ### Format
#
# A data frame with 107 observations on the following 4 variables.
#
# weight
#
# Body mass in Kg for "typical adult sizes"
#
# speed
#
# Maximal running speed (fastest sprint velocity on record)
#
# hoppers
#
# logical variable indicating animals that ambulate by hopping, e.g. kangaroos
#
# specials
#
# logical variable indicating special animals with "lifestyles in which speed
# does not figure as an important factor": Hippopotamus, raccoon (Procyon),
# badger (Meles), coati (Nasua), skunk (Mephitis), man (Homo), porcupine
# (Erithizon), oppossum (didelphis), and sloth (Bradypus)
#
# ### Details
#
# ...

# %%
mammals = data('Mammals') # load the dataset and store it in a variable

# %% [markdown]
# 3a) How many rows and columns are there?

# %%
mammals.shape
#this function shows the number of rows and columns
# in the dataframe

#there are 107 rows and 4 columns
# Out:
# (107, 4)

# %% [markdown]
# 3b) What are the data types?

# %%
mammals.dtypes
#this function shows the data type in each column
# Out:
# weight      float64
# speed       float64
# hoppers        bool
# specials       bool
# dtype: object

# %% [markdown]
# 3c) Summarize the dataframe with .info and .describe

# %%
mammals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 107 entries, 1 to 107
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   weight    107 non-null    float64
#  1   speed     107 non-null    float64
#  2   hoppers   107 non-null    bool
#  3   specials  107 non-null    bool
# dtypes: bool(2), float64(2)
# memory usage: 2.7 KB

# %%
mammals.describe()
# Out:
#             weight       speed
# count   107.000000  107.000000
# mean    278.688178   46.208411
# std     839.608269   26.716778
# min       0.016000    1.600000
# 25%       1.700000   22.500000
# 50%      34.000000   48.000000
# 75%     142.500000   65.000000
# max    6000.000000  110.000000

# %% [markdown]
# 3d) What is the the weight of the fastest animal?

# %%
mammals[mammals.speed == mammals.speed.max()].weight
#from the mammals dataframe, retrieve the values from the
#column named 'speed' and retrieve (==) the max value
#once that max value has been indexed, retrieve the weight
# Out:
# 53    55.0
# Name: weight, dtype: float64

# %% [markdown]
# 3f) What is the overal percentage of specials?

# %%
percentage_of_specials = len(mammals[mammals.specials]) / len(mammals) * 100
#create a variable called 'percentage_of_specials'
#find the total amount(len) of True values returned from the column
#names 'specials' in the mammals dataframe and divide it by
#the total amount(len) of rows in the mammals dataframe.
#multiply by 100 to find the perentage
percentage_of_specials
# Out:
# 9.345794392523365

# %% [markdown]
# 3g) How many animals are hoppers that are above the median speed?
# What percentage is this?

# %%
hoppers = mammals[mammals.hoppers]
#create a subdataframe called 'hoppers' that will
#access the mammals dataframe and retrieve mammals
#under the 'hoppers' column 
number_of_hoppers = len(hoppers[hoppers.speed > mammals.speed.median()])
#create a variable callled number_of_hoppers that
#finds the total amount(len) of True values under the 'speed'
#column from the hoppers subdataframe that is 
#greater than the median value under the 'speed'
#column from the mammals dataframe

percentage = number_of_hoppers / len(mammals) * 100
#create a variable called percentage that takes
#in the 'number_of_hoppers' and divides it by the total
#amount of mammals(rows) then multiplies by 100
#to find the percentage value
percentage
# Out:
# 6.5420560747663545
